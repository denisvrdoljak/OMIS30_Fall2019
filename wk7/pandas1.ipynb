# %%
# Standard Python line to import pandas library
# It's imported as 'pd' for less typing later!

import pandas as pd

# %%
# Reading in the file
# Pandas has many built in readers for different file types

df = pd.read_csv("Demographic_Statistics_By_Zip_Code.csv")

# %%
# First - make sure the data loaded correctly by checking the first rows 
# (.head() defaults to 5 rows)

df.head()
# Out:
#    JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0              10001                  44            22            0.50
# 1              10002                  35            19            0.54
# 2              10003                   1             1            1.00
# 3              10004                   0             0            0.00
# 4              10005                   2             2            1.00
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 0          22          0.50                     0                       0
# 1          16          0.46                     0                       0
# 2           0          0.00                     0                       0
# 3           0          0.00                     0                       0
# 4           0          0.00                     0                       0
#
#    COUNT GENDER TOTAL  PERCENT GENDER TOTAL               ...                 \
# ...

# %%
# Can also do a tail(x) to see the last x number of rows in the data (also defaults to 5 using tail() )

df.tail(10)
# Out:
#      JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 226              12764                  64            61            0.95
# 227              12768                  63             1            0.02
# 228              12779                 242           183            0.76
# 229              12783                 201            66            0.33
# 230              12786                   4             3            0.75
# 231              12788                  83            39            0.47
# 232              12789                 272           115            0.42
# 233              13731                  17             2            0.12
# 234              16091                   0             0            0.00
# 235              20459                   0             0            0.00
#
#      COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 226           3          0.05                     0                       0
# ...

# %%
df.columns
# Out:
# Index(['JURISDICTION NAME', 'COUNT PARTICIPANTS', 'COUNT FEMALE',
#        'PERCENT FEMALE', 'COUNT MALE', 'PERCENT MALE', 'COUNT GENDER UNKNOWN',
#        'PERCENT GENDER UNKNOWN', 'COUNT GENDER TOTAL', 'PERCENT GENDER TOTAL',
#        'COUNT PACIFIC ISLANDER', 'PERCENT PACIFIC ISLANDER',
#        'COUNT HISPANIC LATINO', 'PERCENT HISPANIC LATINO',
#        'COUNT AMERICAN INDIAN', 'PERCENT AMERICAN INDIAN',
#        'COUNT ASIAN NON HISPANIC', 'PERCENT ASIAN NON HISPANIC',
#        'COUNT WHITE NON HISPANIC', 'PERCENT WHITE NON HISPANIC',
#        'COUNT BLACK NON HISPANIC', 'PERCENT BLACK NON HISPANIC',
#        'COUNT OTHER ETHNICITY', 'PERCENT OTHER ETHNICITY',
#        'COUNT ETHNICITY UNKNOWN', 'PERCENT ETHNICITY UNKNOWN',
#        'COUNT ETHNICITY TOTAL', 'PERCENT ETHNICITY TOTAL',
#        'COUNT PERMANENT RESIDENT ALIEN', 'PERCENT PERMANENT RESIDENT ALIEN',
#        'COUNT US CITIZEN', 'PERCENT US CITIZEN', 'COUNT OTHER CITIZEN STATUS',
# ...

# %%
df.describe()
# Out:
#        JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# count         236.000000          236.000000    236.000000      236.000000
# mean        11127.173729           17.661017     10.296610        0.243983
# std          1052.431790           43.279737     28.189121        0.333677
# min         10001.000000            0.000000      0.000000        0.000000
# 25%         10451.750000            0.000000      0.000000        0.000000
# 50%         11216.500000            0.000000      0.000000        0.000000
# 75%         11422.250000           13.000000      6.000000        0.515000
# max         20459.000000          272.000000    194.000000        1.000000
#
#        COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# count  236.000000    236.000000                 236.0                   236.0
# mean     7.364407      0.201017                   0.0                     0.0
# ...

# %%
df['PERCENT CITIZEN STATUS TOTAL']
# Out:
# 0      100
# 1      100
# 2      100
# 3        0
# 4      100
# 5      100
# 6      100
# 7      100
# 8        0
# 9      100
# 10       0
# 11     100
# 12       0
# 13     100
# 14       0
# 15     100
# 16       0
# 17       0
# 18       0
# 19     100
# 20     100
# 21     100
# 22     100
# 23       0
# 24     100
# 25       0
# 26     100
# 27       0
# 28       0
# 29     100
#       ...
# 206      0
# 207    100
# 208      0
# 209    100
# 210    100
# 211    100
# 212      0
# 213    100
# 214      0
# 215    100
# 216    100
# 217    100
# 218    100
# 219    100
# 220    100
# 221    100
# 222    100
# 223    100
# 224    100
# 225    100
# 226    100
# 227    100
# 228    100
# 229    100
# 230    100
# 231    100
# 232    100
# 233    100
# 234      0
# 235      0
# Name: PERCENT CITIZEN STATUS TOTAL, Length: 236, dtype: int64

# %%
df[0:1]
# Out:
#    JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0              10001                  44            22             0.5
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 0          22           0.5                     0                       0
#
#    COUNT GENDER TOTAL  PERCENT GENDER TOTAL               ...                 \
# 0                  44                   100               ...
#
#    COUNT CITIZEN STATUS TOTAL  PERCENT CITIZEN STATUS TOTAL  \
# 0                          44                           100
#
#    COUNT RECEIVES PUBLIC ASSISTANCE  PERCENT RECEIVES PUBLIC ASSISTANCE  \
# 0                                20                                0.45
#
#    COUNT NRECEIVES PUBLIC ASSISTANCE  PERCENT NRECEIVES PUBLIC ASSISTANCE  \
# 0                                 24                                 0.55
#
#    COUNT PUBLIC ASSISTANCE UNKNOWN  PERCENT PUBLIC ASSISTANCE UNKNOWN  \
# ...

# %%
df['PERCENT CITIZEN STATUS TOTAL'].value_counts()
# Out:
# 0      131
# 100    104
# 99       1
# Name: PERCENT CITIZEN STATUS TOTAL, dtype: int64

# %%
pd.set_option('display.max_columns', None)
df [ df['PERCENT CITIZEN STATUS TOTAL'] == 99 ]
# Out:
#      JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 125              11224                  93            53            0.57
#
#      COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 125          40          0.43                     0                       0
#
#      COUNT GENDER TOTAL  PERCENT GENDER TOTAL  COUNT PACIFIC ISLANDER  \
# 125                  93                   100                       0
#
#      PERCENT PACIFIC ISLANDER  COUNT HISPANIC LATINO  PERCENT HISPANIC LATINO  \
# 125                       0.0                     14                     0.15
#
#      COUNT AMERICAN INDIAN  PERCENT AMERICAN INDIAN  COUNT ASIAN NON HISPANIC  \
# 125                      0                      0.0                         7
#
#      PERCENT ASIAN NON HISPANIC  COUNT WHITE NON HISPANIC  \
# 125                        0.08                         4
#
#      PERCENT WHITE NON HISPANIC  COUNT BLACK NON HISPANIC  \
# ...

# %%
df['COUNT OTHER CITIZEN STATUS'].mean()
# Out:
# 0.046610169491525424

# %%
df['COUNT OTHER CITIZEN STATUS'].median()
# Out:
# 0.0

# %%
df['COUNT OTHER CITIZEN STATUS'].min()
# Out:
# 0

# %%
df['COUNT OTHER CITIZEN STATUS'].max()
# Out:
# 2

# %%
import matplotlib.pyplot as plt

# %%
df.hist(['COUNT PARTICIPANTS'], bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000088F4128>]],
#       dtype=object)

# %%
df.reset_index().plot(x='index', y='PERCENT OTHER CITIZEN STATUS')

# %%
df.plot.scatter(x='JURISDICTION NAME', y='COUNT PARTICIPANTS')
